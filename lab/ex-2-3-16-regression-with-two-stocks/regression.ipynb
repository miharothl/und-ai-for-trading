# %% [markdown]
# # Regression

# %% [markdown]
# ## Install packages

# %%
import sys
# !{sys.executable} -m pip install -r requirements.txt
# Out:
# Requirement already satisfied: statsmodels==0.9.0 in /usr/local/anaconda3/envs/und-ai-trading-lab/lib/python3.6/site-packages (from -r requirements.txt (line 1)) (0.9.0)
# Requirement already satisfied: colour==0.1.5 in /usr/local/anaconda3/envs/und-ai-trading-lab/lib/python3.6/site-packages (from -r requirements.txt (line 2)) (0.1.5)
# Requirement already satisfied: numpy>=1.15 in /usr/local/anaconda3/envs/und-ai-trading-lab/lib/python3.6/site-packages (from -r requirements.txt (line 3)) (1.19.5)
# Requirement already satisfied: pandas==0.21.1 in /usr/local/anaconda3/envs/und-ai-trading-lab/lib/python3.6/site-packages (from -r requirements.txt (line 4)) (0.21.1)
# Requirement already satisfied: plotly==2.2.3 in /usr/local/anaconda3/envs/und-ai-trading-lab/lib/python3.6/site-packages (from -r requirements.txt (line 5)) (2.2.3)
# Requirement already satisfied: scikit-learn==0.19.1 in /usr/local/anaconda3/envs/und-ai-trading-lab/lib/python3.6/site-packages (from -r requirements.txt (line 6)) (0.19.1)
# Requirement already satisfied: six==1.11.0 in /usr/local/anaconda3/envs/und-ai-trading-lab/lib/python3.6/site-packages (from -r requirements.txt (line 7)) (1.11.0)
# Requirement already satisfied: tqdm in /usr/local/anaconda3/envs/und-ai-trading-lab/lib/python3.6/site-packages (from -r requirements.txt (line 8)) (4.64.0)
# Requirement already satisfied: patsy in /usr/local/anaconda3/envs/und-ai-trading-lab/lib/python3.6/site-packages (from statsmodels==0.9.0->-r requirements.txt (line 1)) (0.5.2)
# Requirement already satisfied: pytz>=2011k in /usr/local/anaconda3/envs/und-ai-trading-lab/lib/python3.6/site-packages (from pandas==0.21.1->-r requirements.txt (line 4)) (2022.1)
# Requirement already satisfied: python-dateutil>=2 in /usr/local/anaconda3/envs/und-ai-trading-lab/lib/python3.6/site-packages (from pandas==0.21.1->-r requirements.txt (line 4)) (2.8.2)
# Requirement already satisfied: decorator>=4.0.6 in /usr/local/anaconda3/envs/und-ai-trading-lab/lib/python3.6/site-packages (from plotly==2.2.3->-r requirements.txt (line 5)) (5.1.1)
# Requirement already satisfied: requests in /usr/local/anaconda3/envs/und-ai-trading-lab/lib/python3.6/site-packages (from plotly==2.2.3->-r requirements.txt (line 5)) (2.27.1)
# Requirement already satisfied: nbformat>=4.2 in /usr/local/anaconda3/envs/und-ai-trading-lab/lib/python3.6/site-packages (from plotly==2.2.3->-r requirements.txt (line 5)) (5.1.3)
# Requirement already satisfied: importlib-resources in /usr/local/anaconda3/envs/und-ai-trading-lab/lib/python3.6/site-packages (from tqdm->-r requirements.txt (line 8)) (5.4.0)
# Requirement already satisfied: jupyter-core in /usr/local/anaconda3/envs/und-ai-trading-lab/lib/python3.6/site-packages (from nbformat>=4.2->plotly==2.2.3->-r requirements.txt (line 5)) (4.9.2)
# Requirement already satisfied: traitlets>=4.1 in /usr/local/anaconda3/envs/und-ai-trading-lab/lib/python3.6/site-packages (from nbformat>=4.2->plotly==2.2.3->-r requirements.txt (line 5)) (4.3.3)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/local/anaconda3/envs/und-ai-trading-lab/lib/python3.6/site-packages (from nbformat>=4.2->plotly==2.2.3->-r requirements.txt (line 5)) (3.2.0)
# Requirement already satisfied: ipython-genutils in /usr/local/anaconda3/envs/und-ai-trading-lab/lib/python3.6/site-packages (from nbformat>=4.2->plotly==2.2.3->-r requirements.txt (line 5)) (0.2.0)
# Requirement already satisfied: importlib-metadata in /usr/local/anaconda3/envs/und-ai-trading-lab/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2->plotly==2.2.3->-r requirements.txt (line 5)) (4.8.3)
# Requirement already satisfied: setuptools in /usr/local/anaconda3/envs/und-ai-trading-lab/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2->plotly==2.2.3->-r requirements.txt (line 5)) (58.0.4)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/anaconda3/envs/und-ai-trading-lab/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2->plotly==2.2.3->-r requirements.txt (line 5)) (21.4.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /usr/local/anaconda3/envs/und-ai-trading-lab/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2->plotly==2.2.3->-r requirements.txt (line 5)) (0.18.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/anaconda3/envs/und-ai-trading-lab/lib/python3.6/site-packages (from importlib-metadata->jsonschema!=2.5.0,>=2.4->nbformat>=4.2->plotly==2.2.3->-r requirements.txt (line 5)) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/anaconda3/envs/und-ai-trading-lab/lib/python3.6/site-packages (from importlib-metadata->jsonschema!=2.5.0,>=2.4->nbformat>=4.2->plotly==2.2.3->-r requirements.txt (line 5)) (3.6.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/anaconda3/envs/und-ai-trading-lab/lib/python3.6/site-packages (from requests->plotly==2.2.3->-r requirements.txt (line 5)) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/anaconda3/envs/und-ai-trading-lab/lib/python3.6/site-packages (from requests->plotly==2.2.3->-r requirements.txt (line 5)) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/anaconda3/envs/und-ai-trading-lab/lib/python3.6/site-packages (from requests->plotly==2.2.3->-r requirements.txt (line 5)) (2021.5.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/anaconda3/envs/und-ai-trading-lab/lib/python3.6/site-packages (from requests->plotly==2.2.3->-r requirements.txt (line 5)) (1.26.9)

# %%
import pandas as pd
import numpy as np
import os
import helper
import quiz_tests
import matplotlib.pyplot as plt

# %%
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (14, 8)

# %% [markdown]
# ## Simulate two stock prices

# %%
# just set the seed for the random number generator
np.random.seed(100)
# use returns to create a price series
drift = 100
r0 = pd.Series(np.random.normal(0, 1, 1000))
s0 = pd.Series(np.cumsum(r0), name='s0') + drift

noise1 = np.random.normal(0, 0.4, 1000)
drift1 = 50
r1 = r0 + noise1
s1 = pd.Series(np.cumsum(r1), name='s1') + drift1

noise2 = np.random.normal(0, 0.4, 1000)
drift2 = 60
r2 = r0 + noise2
s2 = pd.Series(np.cumsum(r2), name='s2') + drift2

pd.concat([s1, s2], axis=1).plot(figsize=(15,6))
plt.show()

# %%
## Plot data with scatterplot
sc = plt.scatter(s2, s1, s=30, edgecolor='b', alpha=0.7)
plt.xlabel('s2')
plt.ylabel('s1');

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Quiz: Linear Regression
#
# Note that the LinearRegression().fit() expects 2D numpy arrays.  Since s1 and s2 are pandas series, we can use Series.values to get the values as a numpy array. Since these are 1D arrays, we can use numpy.reshape(-1,1) to make these 1000 row by 1 column 2 dimensional arrays.
#
# The coefficients of the linear regression, $\beta$ and $intercept$ for the regression line:
# $y = \beta \times x + intercept$
# Can be obtained after fitting to the data.  Use `LinearRegression.coef_` for the slope (beta coefficients) and `LinearRegression.intercept_` for the intercept.  You may want to practice accessing these outside of the function definition, to see if you'll need additional brackets `[]` to access the values.

# %%
def regression_slope_and_intercept(xSeries, ySeries):
    """
    xSeries: pandas series, x variable
    ySeries: pandas series, y variable
    """
    lr = LinearRegression()
    #TODO: get the values from each series, reshape to be 2 dimensional
    #set s1 to the x variable, s2 to the y variable
    xVar = xSeries.values.reshape(-1,1)
    yVar = ySeries.values.reshape(-1,1)
    
    #TODO: call LinearRegression.fit().  Pass in the x variable then y variable
    lr.fit(xVar,yVar);
    
    #TODO: obtain the slope and intercept
    slope = lr.coef_[0][0]
    intercept = lr.intercept_[0]
        
    return (slope, intercept)

quiz_tests.test_regression_slope_and_intercept(regression_slope_and_intercept);
# Out:
# Tests Passed

# %%
slope, intercept = regression_slope_and_intercept(s1,s2);
print(f"slope {slope:.2f} and intercept {intercept:.2f}")
# Out:
# slope 0.74 and intercept 30.62

# %% [markdown]
# ### Plot the fitted regression line over the scatterplot

# %%
plt.scatter(s2, s1, s=30, edgecolor='b', alpha=0.5);
x = np.linspace(s1.min()-5, s1.max()+5, 2)
yPred = slope * x + intercept
plt.plot(yPred,x, alpha=0.2, lw=3, color='r')
plt.xlabel('s2')
plt.ylabel('s1');

# %% [markdown]
# If you're stuck, you can also check out the solution [here](regression_solution.ipynb)
